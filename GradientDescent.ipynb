# %%
import numpy as np
from sklearn import preprocessing
from sklearn import model_selection

# %%
training=np.loadtxt('training_boston_x_y_train.csv', delimiter=',')
testing=np.loadtxt('test_boston_x_test.csv', delimiter=',')

# %%
print(testing.shape)
# Out:
# (127, 13)

# %%
def step_gradient(X, Y, m, learning_rate):
    m_slope=np.zeros(len(X[0]))
    for i in range(len(X)):
        x=X[i]
        y=Y[i]
        for j in range(len(x)):
            m_slope[j]+=(-2/len(X))*(y-sum(m*x))*x[j]
    new_m=m-(learning_rate*m_slope)
    return new_m

def cost(m, x, y):
    cost=0
    for i in range(len(x)):
        cost+=(1/len(x))*((y[i]-sum(m*x[i]))**2)
    print(cost)

def gd(x, y, learning_rate, iterations):
    m=np.zeros(len(x[0]))
    for i in range(iterations):
        m=step_gradient(x, y, m, learning_rate)
        print("itr= ", i, "cost=", end=' ')
        cost(m,x,y)
    return m

def gradient_descent(x, y):
    iterations=200
    learning_rate=0.0385
    x=np.append(x, np.ones(len(x)).reshape(-1, 1), axis=1)
    m=gd(x, y, learning_rate, iterations)
    return m

# %%
x=training[:, :-1]
y=training[:, -1]
power=[]
for i in range(2,5):
    li=[]
    for j in x:
        li.append(j**i)
    
    power.append(li)

power=np.array(power)
print(power.shape)
# Out:
# (3, 379, 13)

# %%
for i in range(power.shape[0]):
    x=np.append(x,power[i],axis=1)

# %%
x.shape
# Out:
# (379, 52)

# %%
# x=training[:, :-1]
# y=training[:, -1]
# #adding squared values of each column
# power=[]
# for i in range(2,11):
#     li=[]
#     for j in x:
#         li.append(j**i)
    
#     power.append(li)

# power=np.array(power)
    
# sq=[]
# cu=[]
# fo=[]
# fi=[]
# for i in x:
#     sq.append(i**2)
    
# for i in x:
#     cu.append(i**3)
    
# for i in x:
#     fo.append(i**4)

# for i in x:
#     fi.append(i**5)
    
# sq=np.array(sq)
# cu=np.array(cu)
# fo=np.array(fo)
# fi
# x=np.append(x, sq, axis=1)
# x=np.append(x,cu,axis=1)



    
# print(x.shape)

scaler=preprocessing.StandardScaler()
scaler.fit(x)
x=scaler.transform(x)
m=gradient_descent(x, y)
# Out:
# itr=  0 cost= 481.886895953797
# itr=  1 cost= 409.23725144765854
# itr=  2 cost= 349.5921670451017
# itr=  3 cost= 299.8894350106253
# itr=  4 cost= 258.12028075994033
# itr=  5 cost= 222.83445090959933
# itr=  6 cost= 192.92511235478597
# itr=  7 cost= 167.51587364026236
# itr=  8 cost= 145.8957883653791
# itr=  9 cost= 127.47881991063369
# itr=  10 cost= 111.7767340502412
# itr=  11 cost= 98.3798760643999
# itr=  12 cost= 86.94287424071786
# itr=  13 cost= 77.17360413100351
# itr=  14 cost= 68.82442741814936
# itr=  15 cost= 61.685092168371
# itr=  16 cost= 55.57689407431322
# itr=  17 cost= 50.34782451091429
# itr=  18 cost= 45.86850911372087
# itr=  19 cost= 42.02879070836401
# itr=  20 cost= 38.73484409296328
# itr=  21 cost= 35.90673378273856
# itr=  22 cost= 33.47634304670174
# itr=  23 cost= 31.38561557373475
# itr=  24 cost= 29.58506122005776
# itr=  25 cost= 28.032485339503914
# itr=  26 cost= 26.69190771890088
# itr=  27 cost= 25.532642494479443
# itr=  28 cost= 24.52851486405228
# itr=  29 cost= 23.657194116617696
# itr=  30 cost= 22.89962561297638
# itr=  31 cost= 22.23954697334024
# itr=  32 cost= 21.663075943903852
# itr=  33 cost= 21.158359290705953
# itr=  34 cost= 20.715273660251526
# itr=  35 cost= 20.325170697130535
# itr=  36 cost= 19.98065985651011
# itr=  37 cost= 19.675423325037475
# itr=  38 cost= 19.40405829352882
# itr=  39 cost= 19.16194253087803
# itr=  40 cost= 18.945119809525078
# itr=  41 cost= 18.750202244345857
# itr=  42 cost= 18.574287042330024
# itr=  43 cost= 18.414885531244586
# itr=  44 cost= 18.269862651278906
# itr=  45 cost= 18.137385362617213
# itr=  46 cost= 18.015878650955955
# itr=  47 cost= 17.903988008096512
# itr=  48 cost= 17.800547430944487
# itr=  49 cost= 17.704552123821244
# itr=  50 cost= 17.61513520959634
# itr=  51 cost= 17.53154785789245
# itr=  52 cost= 17.45314232613972
# itr=  53 cost= 17.379357483825935
# itr=  54 cost= 17.309706453816748
# itr=  55 cost= 17.243766058745827
# itr=  56 cost= 17.181167806588697
# itr=  57 cost= 17.121590188824804
# itr=  58 cost= 17.064752098068134
# itr=  59 cost= 17.01040720057084
# itr=  60 cost= 16.958339123308008
# itr=  61 cost= 16.90835733606165
# itr=  62 cost= 16.8602936265676
# itr=  63 cost= 16.81399908182732
# itr=  64 cost= 16.769341501499685
# itr=  65 cost= 16.726203180208405
# itr=  66 cost= 16.684479004906063
# itr=  67 cost= 16.64407482136742
# itr=  68 cost= 16.604906030643086
# itr=  69 cost= 16.566896382065906
# itr=  70 cost= 16.529976934312756
# itr=  71 cost= 16.494085160209654
# itr=  72 cost= 16.45916417453571
# itr=  73 cost= 16.425162067123036
# itr=  74 cost= 16.392031326142266
# itr=  75 cost= 16.35972833867432
# itr=  76 cost= 16.32821295755363
# itr=  77 cost= 16.297448125075295
# itr=  78 cost= 16.26739954552947
# itr=  79 cost= 16.23803539969513
# itr=  80 cost= 16.209326095422597
# itr=  81 cost= 16.18124404928481
# itr=  82 cost= 16.153763495002792
# itr=  83 cost= 16.126860314970845
# itr=  84 cost= 16.10051189173427
# itr=  85 cost= 16.074696976724983
# itr=  86 cost= 16.049395573944427
# itr=  87 cost= 16.024588836612732
# itr=  88 cost= 16.000258975084126
# itr=  89 cost= 15.976389174567876
# itr=  90 cost= 15.952963521400294
# itr=  91 cost= 15.929966936787833
# itr=  92 cost= 15.90738511709171
# itr=  93 cost= 15.88520447985283
# itr=  94 cost= 15.863412114865408
# itr=  95 cost= 15.841995739701973
# itr=  96 cost= 15.82094365917271
# itr=  97 cost= 15.800244728271698
# itr=  98 cost= 15.779888318221298
# itr=  99 cost= 15.759864285276876
# itr=  100 cost= 15.740162941998422
# itr=  101 cost= 15.72077503073199
# itr=  102 cost= 15.701691699077235
# itr=  103 cost= 15.68290447714486
# itr=  104 cost= 15.664405256431262
# itr=  105 cost= 15.646186270159244
# itr=  106 cost= 15.628240074950911
# itr=  107 cost= 15.61055953371443
# itr=  108 cost= 15.593137799640429
# itr=  109 cost= 15.575968301214065
# itr=  110 cost= 15.559044728160703
# itr=  111 cost= 15.54236101825031
# itr=  112 cost= 15.525911344894567
# itr=  113 cost= 15.509690105476697
# itr=  114 cost= 15.493691910360333
# itr=  115 cost= 15.477911572528601
# itr=  116 cost= 15.462344097809538
# itr=  117 cost= 15.446984675647467
# itr=  118 cost= 15.431828670384018
# itr=  119 cost= 15.416871613015372
# itr=  120 cost= 15.4021091933951
# itr=  121 cost= 15.387537252854438
# itr=  122 cost= 15.3731517772144
# itr=  123 cost= 15.358948890165573
# itr=  124 cost= 15.344924846993871
# itr=  125 cost= 15.331076028631532
# itr=  126 cost= 15.31739893601453
# itr=  127 cost= 15.303890184728873
# itr=  128 cost= 15.29054649992923
# itr=  129 cost= 15.27736471151457
# itr=  130 cost= 15.264341749546649
# itr=  131 cost= 15.251474639897825
# itr=  132 cost= 15.238760500115738
# itr=  133 cost= 15.226196535492972
# itr=  134 cost= 15.213780035330986
# itr=  135 cost= 15.201508369387525
# itr=  136 cost= 15.189378984498072
# itr=  137 cost= 15.17738940136198
# itr=  138 cost= 15.165537211484734
# itr=  139 cost= 15.153820074268165
# itr=  140 cost= 15.142235714240995
# itr=  141 cost= 15.130781918422157
# itr=  142 cost= 15.119456533810485
# itr=  143 cost= 15.108257464993995
# itr=  144 cost= 15.097182671872552
# itr=  145 cost= 15.086230167488619
# itr=  146 cost= 15.075398015959914
# itr=  147 cost= 15.064684330509321
# itr=  148 cost= 15.054087271587129
# itr=  149 cost= 15.043605045080438
# itr=  150 cost= 15.033235900606043
# itr=  151 cost= 15.022978129882153
# itr=  152 cost= 15.012830065174995
# itr=  153 cost= 15.002790077816943
# itr=  154 cost= 14.992856576792178
# itr=  155 cost= 14.983028007386727
# itr=  156 cost= 14.973302849899717
# itr=  157 cost= 14.963679618412753
# itr=  158 cost= 14.95415685961451
# itr=  159 cost= 14.944733151677998
# itr=  160 cost= 14.935407103187561
# itr=  161 cost= 14.926177352113665
# itr=  162 cost= 14.91704256483259
# itr=  163 cost= 14.908001435189373
# itr=  164 cost= 14.899052683601386
# itr=  165 cost= 14.890195056200923
# itr=  166 cost= 14.881427324014819
# itr=  167 cost= 14.872748282179206
# itr=  168 cost= 14.864156749187803
# itr=  169 cost= 14.855651566172122
# itr=  170 cost= 14.847231596212014
# itr=  171 cost= 14.838895723675046
# itr=  172 cost= 14.83064285358359
# itr=  173 cost= 14.822471911007863
# itr=  174 cost= 14.814381840484165
# itr=  175 cost= 14.806371605456635
# itr=  176 cost= 14.798440187741868
# itr=  177 cost= 14.790586587014992
# itr=  178 cost= 14.782809820316341
# itr=  179 cost= 14.775108921577678
# itr=  180 cost= 14.767482941167048
# itr=  181 cost= 14.759930945451595
# itr=  182 cost= 14.752452016377234
# itr=  183 cost= 14.745045251064356
# itr=  184 cost= 14.737709761419326
# itr=  185 cost= 14.730444673760344
# itr=  186 cost= 14.723249128457555
# itr=  187 cost= 14.716122279586534
# itr=  188 cost= 14.709063294594412
# itr=  189 cost= 14.702071353978447
# itr=  190 cost= 14.695145650976071
# itr=  191 cost= 14.688285391266104
# itr=  192 cost= 14.68148979268064
# itr=  193 cost= 14.674758084926998
# itr=  194 cost= 14.66808950931952
# itr=  195 cost= 14.661483318520448
# itr=  196 cost= 14.65493877628983
# itr=  197 cost= 14.648455157243792
# itr=  198 cost= 14.642031746620928
# itr=  199 cost= 14.63566784005647

# %%
power2=[]
for i in range(2,11):
    li=[]
    for j in testing:
        li.append(j**i)
    
    power2.append(li)

power2=np.array(power2)
print(power2.shape)
# Out:
# (9, 127, 13)

# %%
for i in range(power2.shape[0]):
    testing=np.append(testing,power2[i],axis=1)

# %%
print(testing.shape)
# Out:
# (127, 130)

# %%
# sq=[]
# cu=[]
# for i in testing:
#     sq.append(i**2)
    
# for i in testing:
#     cu.append(i**3)
    
# sq=np.array(sq)
# cu=np.array(cu)
# print(cu.shape)
# testing=np.append(testing, sq, axis=1)
# testing=np.append(testing,cu,axis=1)
# print(testing.shape)
# Out:
# (127, 13)
# (127, 39)

# %%
# sq=[]
# cu=[]
# for i in testing:
#     sq.append(i**2)
# for i in testing:
#     cu.append(i**3)
    
# sq=np.array(sq)
# cu=np.array(cu)
# print(testing.shape)


# testing=np.append(testing, sq, axis=1)
# print(testing.shape)
# testing=np.append(testing, cu, axis=1)

#print(testing.shape)
testing1=scaler.transform(testing)
x_test=np.append(testing1, np.ones(len(testing1)).reshape(-1, 1), axis=1)
ans=[]
for i in x_test:
    ans.append(sum(i*m))
for i in ans:
    print(i)
ans=np.array(ans)
np.savetxt('predicted2.csv',ans,delimiter=',')
#np.savetxt(X=ans,fname='Prediction.csv',delimiter=',', fmt='%.5f')
# Out:
# -14086.623980958075
# 21.32731885399117
# 23.273741197629988
# -75.64991482458149
# 20.609880952860983
# -13284.911250877572
# 34.644260727595125
# 39.36251068528554
# 20.194051251305826
# 27.085764688973192
# 11.7377868730233
# 18.095484343624815
# -110.57351562420669
# 21.895819674149244
# -28351.45250668995
# -44.62351497861895
# -1422.406845334206
# 28.638247527820322
# -3.2353931742260045
# 33.970705890508775
# 24.688907045602708
# -107.0069999467037
# -92.05188041085697
# 60756.43411115631
# 753.9242767294523
# 114.45680102187623
# 26.274724955687496
# -2.8994060787326212
# 60743.202054804744
# 60749.673141094885
# 17.239848016373266
# -1466.493714198342
# 23.635428635456407
# 28.159774028054883
# -1457.4686639868382
# 30.404222372353694
# 21.58603904849741
# 20.52135683709307
# 21.09564246710994
# 165552.50048197605
# -59287.217286430256
# -150.63144144034396
# 1418.698493288472
# -10.256784932768412
# 116.30037425994183
# -20329.33872940432
# -393773.63714252284
# 27.057198926465894
# 28014.612016391027
# 188.33000953658578
# 120.86999436776921
# 46112.078215584384
# 188.87999914228368
# 24.836249850300074
# 16.56803716103094
# 29.800605351487157
# 20.806366811440437
# 12.8667807756421
# 16.627473371583797
# 131.34566447161598
# -79449.20358430008
# 36.604563481364856
# 24.70538664549312
# 30.142716190516246
# 124.22068682007196
# 179478.5782877029
# -5182.583094177766
# 132.01726605981003
# 60745.02794987823
# 119.93634502776834
# 32.11646069335692
# -105.75454266965832
# 10325.468355064211
# -6053.921258269886
# 28313.344906370316
# 27.73920063793518
# 24.44089881065667
# -229.37061581310996
# 67.8954195882444
# -2637.8270279874487
# 408.25864248118006
# 22.883980364975066
# -12.569168546465974
# -1986.9387258381894
# 131.1491441890181
# 44.13599812894776
# 25.514571795215105
# -2411.1364297517653
# -421.60158555968536
# 122.04658742615604
# -186.8900565160147
# 22.56097012260107
# 22.422331510996337
# 103285.28532169884
# 22.14021814602526
# 10332.25837612243
# 829.9788542785008
# -422.9724237478445
# 3477.498186285873
# 49.76923164856028
# -5147.979781196112
# -7.853272557576492
# 60747.294557897316
# 30.959269297536924
# 356935.2611805878
# 29.293333985245116
# 16.722114942303822
# 9298.845959365915
# -74.58622666677675
# 14661.90345121342
# 74.61524812291137
# -119835.59317707222
# 14.985091748250943
# -247.68328874808353
# -5038.5123325047425
# 42085.16582189345
# 21.016098943093937
# 19.357192663633064
# -74.49401286967824
# 10322.686625911698
# 15.624771293568358
# -35.6468686787279
# 23.218056523478555
# 24.353215558229156
# -12948.810142323484
# 21.451633891273286
# 32891.13385779764
